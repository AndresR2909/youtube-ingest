# %%
pip install --upgrade -r requirements.txt -q
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import io
import logging
from datetime import datetime
import azure.functions as func
from logic.data_ingestion import DataIngestion
from logic.blob_storage import BlobStorageManager

from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
DELTA_DAYS = os.environ.get('DELTA_DAYS')
DELTA_HOURS = os.environ.get('DELTA_HOURS')
CHANNEL_LIST = os.environ.get('CHANNEL_LIST')
SCHEDULE = os.environ.get('CRON_SCHEDULE')

# %%
data_ingestion = DataIngestion()
bsm = BlobStorageManager()

# %%
chanel_list = CHANNEL_LIST.split(',')

# %%
chanel_list
# Out:
# ['https://www.youtube.com/@Crecetrader/videos',
#  'https://www.youtube.com/@Crecetrader/shorts',
#  'https://www.youtube.com/@BitcoinHoyOficial/videos',
#  'https://www.youtube.com/@BitcoinHoyOficial/shorts',
#  'https://www.youtube.com/@arenaalfa/videos',
#  'https://www.youtube.com/@arenaalfa/shorts',
#  'https://www.youtube.com/@USACRYPTONOTICIAS/videos',
#  'https://www.youtube.com/@USACRYPTONOTICIAS/shorts',
#  'https://www.youtube.com/@USACRYPTONOTICIAS/streams',
#  'https://www.youtube.com/@BitcoinHoyOficial/streams',
#  'https://www.youtube.com/@arenaalfa/streams',
#  'https://www.youtube.com/@Crecetrader/streams']

# %%
list_df = data_ingestion.full_load_from_youtube_channel(chanel_list,output_path="data",filename="full_ingest")
# Out:
# Procesando urls:   0%|          | 0/3 [00:00<?, ?it/s]
# Something went wrong with transcript_list
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=hHPlH62knSE! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Something went wrong with transcript_list
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=Jfb94y5z8kA! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Something went wrong with transcript_list
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=9_91uE05BPE! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Something went wrong with transcript_list
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=pLgygQEPwvs! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Something went wrong with transcript_list
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=PiuwNj15Nv8! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Something went wrong with transcript_list
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=fHpsbPovocE! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Something went wrong with transcript_list
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=Nn51st9Ea4I! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Something went wrong with transcript_list
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=YiVZ_aAK0Uk! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Something went wrong with transcript_list
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=d-6Ud3BhQ0I! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Something went wrong with transcript_list
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=TgOtsgQXZVA! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Something went wrong with transcript_list
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=b55yPoEiNgU! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Something went wrong with transcript_list
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=SZ39_9PSlZ0! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Something went wrong with transcript_list
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=B54Y6fh3bfc! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Something went wrong with transcript_list
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=_RaRu7AgFLI! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Something went wrong with transcript_list
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=iD9NXkkVYGs! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Something went wrong with transcript_list
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=JLFL2QA1cFo! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Something went wrong with transcript_list
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=o-n7-InRQoI! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Procesando urls:  33%|███▎      | 1/3 [00:47<01:34, 47.33s/it]
# Something went wrong with transcript_list
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=-Xx2Zf4ULOY! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Something went wrong with transcript_list
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=BBR2WTr-Oro! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Procesando urls:  67%|██████▋   | 2/3 [00:57<00:25, 25.54s/it]
# Something went wrong with transcript_list
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=Hbub-W1y-HQ! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Something went wrong with transcript_list
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=bQBx-Dh6t2I! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Something went wrong with transcript_list
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=R0v93FDUp3Q! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Procesando urls: 100%|██████████| 3/3 [01:13<00:00, 24.42s/it]

# %%
import os
import pandas as pd

# Directorio que contiene los archivos CSV
folder_path = 'data'

# Lista para almacenar los DataFrames
dataframes = []

# Iterar sobre los archivos en el folder
for file_name in os.listdir(folder_path):
    if file_name.endswith('.csv'):
        # Leer cada archivo CSV en un DataFrame
        df = pd.read_csv(os.path.join(folder_path, file_name),sep=";")
        # Añadirlo a la lista
        dataframes.append(df)

df_concatenado = pd.concat(dataframes, ignore_index=True)

df_concatenado
# Out:
#            channel_name                channel_id  \
# 0           ARENA ALFA   UCOIk09EE_Xfp7PB5LQPXhtg
# 1           ARENA ALFA   UCOIk09EE_Xfp7PB5LQPXhtg
# 2           ARENA ALFA   UCOIk09EE_Xfp7PB5LQPXhtg
# 3           ARENA ALFA   UCOIk09EE_Xfp7PB5LQPXhtg
# 4           ARENA ALFA   UCOIk09EE_Xfp7PB5LQPXhtg
# ...                 ...                       ...
# 3751  USACRYPTONOTICIAS  UCY8AYdix1el08AEFzzwS3Yg
# 3752  USACRYPTONOTICIAS  UCY8AYdix1el08AEFzzwS3Yg
# 3753  USACRYPTONOTICIAS  UCY8AYdix1el08AEFzzwS3Yg
# 3754  USACRYPTONOTICIAS  UCY8AYdix1el08AEFzzwS3Yg
# 3755  USACRYPTONOTICIAS  UCY8AYdix1el08AEFzzwS3Yg
#
#                                             channel_url     video_id  \
# 0     https://www.youtube.com/channel/UCOIk09EE_Xfp7...  YIL_MDG0KC4
# 1     https://www.youtube.com/channel/UCOIk09EE_Xfp7...  K3iB9_cvRNg
# 2     https://www.youtube.com/channel/UCOIk09EE_Xfp7...  yR7itzc-i4k
# 3     https://www.youtube.com/channel/UCOIk09EE_Xfp7...  GwBiqNmv9uc
# 4     https://www.youtube.com/channel/UCOIk09EE_Xfp7...  aL_Zx5FCmhQ
# ...                                                 ...          ...
# 3751  https://www.youtube.com/channel/UCY8AYdix1el08...  GOb6dzwNcQw
# 3752  https://www.youtube.com/channel/UCY8AYdix1el08...  d5s-V6rSkcM
# 3753  https://www.youtube.com/channel/UCY8AYdix1el08...  S7AJkwCJsr8
# 3754  https://www.youtube.com/channel/UCY8AYdix1el08...  haxi3xxLRus
# 3755  https://www.youtube.com/channel/UCY8AYdix1el08...  O_sVMFgLDJI
#
#                                                   title  \
# 0     Palantir: ¿Oportunidad de oro o burbuja a punt...
# 1     Las MEJORES Bolsas de Valores en 2025 ¡Descúbr...
# 2     ¿Cómo DeepSeek Está Cambiando el Juego en los ...
# 3     ¡Acciones de Nubank en Caída! ¿Momento para Co...
# 4     ¡Bombazo en la Bolsa de Colombia! GEA Divide a...
# ...                                                 ...
# 3751  CAYÓ METAVERSO POR CAÍDA DE BITCOIN? NOTICIAS ...
# 3752  SANDBOX: CRIPTOMONEDA QUÉ LO HARÁ MILLONARIO 2...
# 3753  UFO: CRYPTOMONEDA del METAVERSO qué te HARÁ MI...
# 3754  ECOMI (OMI): CRYPTOMONEDA del METAVERSO qué te...
# 3755  CRYPTOMONEDAS DEL METAVERSO | TOP METAVERSE CR...
#
#                                               url  \
# 0     https://www.youtube.com/watch?v=YIL_MDG0KC4
# 1     https://www.youtube.com/watch?v=K3iB9_cvRNg
# 2     https://www.youtube.com/watch?v=yR7itzc-i4k
# 3     https://www.youtube.com/watch?v=GwBiqNmv9uc
# 4     https://www.youtube.com/watch?v=aL_Zx5FCmhQ
# ...                                           ...
# 3751  https://www.youtube.com/watch?v=GOb6dzwNcQw
# 3752  https://www.youtube.com/watch?v=d5s-V6rSkcM
# 3753  https://www.youtube.com/watch?v=S7AJkwCJsr8
# 3754  https://www.youtube.com/watch?v=haxi3xxLRus
# 3755  https://www.youtube.com/watch?v=O_sVMFgLDJI
#
#                                             description  duration  view_count  \
# 0     En este video, analizamos múltiplos de Palanti...     837.0     17126.0
# 1     Descubre las bolsas de valores con mayor creci...     876.0     13435.0
# 2     ¿Qué está ocurriendo en el mundo tecnológico? ...    1022.0     21344.0
# 3     Las acciones de Nubank están en caída libre, s...     945.0     52607.0
# 4     ¡El GEA está cambiando las reglas del juego! L...    1185.0     18060.0
# ...                                                 ...       ...         ...
# 3751  CAYÓ METAVERSO POR CAÍDA DE BITCOIN? \nPRECIO ...     645.0       240.0
# 3752  CRIPTOMONEDA QUE LO HARA MILLONARIO 2022\nSAND...    1055.0       250.0
# 3753  Cómo comprar UFO?\nEnlace BITMART: https://www...    1436.0      3697.0
# 3754  Enlace BITMART: https://www.bitmart.com/en?r=R...    1695.0      2415.0
# 3755  The hottest trends in crypto right now are mem...    1876.0       290.0
#
#       keywords  ... caption_text_az caption_text_be  caption_text_bs  \
# 0          NaN  ...             NaN             NaN              NaN
# 1          NaN  ...             NaN             NaN              NaN
# 2          NaN  ...             NaN             NaN              NaN
# 3          NaN  ...             NaN             NaN              NaN
# 4          NaN  ...             NaN             NaN              NaN
# ...        ...  ...             ...             ...              ...
# 3751       NaN  ...             NaN             NaN              NaN
# 3752       NaN  ...             NaN             NaN              NaN
# 3753       NaN  ...             NaN             NaN              NaN
# 3754       NaN  ...             NaN             NaN              NaN
# 3755       NaN  ...             NaN             NaN              NaN
#
#       caption_text_zh-Hans  caption_text_hr caption_text_sk caption_text_sl  \
# 0                      NaN              NaN             NaN             NaN
# 1                      NaN              NaN             NaN             NaN
# 2                      NaN              NaN             NaN             NaN
# 3                      NaN              NaN             NaN             NaN
# 4                      NaN              NaN             NaN             NaN
# ...                    ...              ...             ...             ...
# 3751                   NaN              NaN             NaN             NaN
# 3752                   NaN              NaN             NaN             NaN
# 3753                   NaN              NaN             NaN             NaN
# 3754                   NaN              NaN             NaN             NaN
# 3755                   NaN              NaN             NaN             NaN
#
#      caption_text_uz caption_text_zh-Hant caption_text_ht
# 0                NaN                  NaN             NaN
# 1                NaN                  NaN             NaN
# 2                NaN                  NaN             NaN
# 3                NaN                  NaN             NaN
# 4                NaN                  NaN             NaN
# ...              ...                  ...             ...
# 3751             NaN                  NaN             NaN
# 3752             NaN                  NaN             NaN
# 3753             NaN                  NaN             NaN
# 3754             NaN                  NaN             NaN
# 3755             NaN                  NaN             NaN
#
# [3756 rows x 57 columns]

# %%
df_concatenado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3756 entries, 0 to 3755
# Data columns (total 57 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   channel_name          3756 non-null   object
#  1   channel_id            3756 non-null   object
#  2   channel_url           3756 non-null   object
#  3   video_id              3756 non-null   object
#  4   title                 3756 non-null   object
#  5   url                   3756 non-null   object
#  6   description           3686 non-null   object
#  7   duration              3691 non-null   float64
#  8   view_count            3753 non-null   float64
#  9   keywords              0 non-null      float64
#  10  publish_date          2463 non-null   object
#  11  relativeDateText      3756 non-null   object
#  12  total_length          3756 non-null   int64
#  13  total_views           3756 non-null   int64
#  14  video_rating          0 non-null      float64
#  15  caption_text_es       2401 non-null   object
#  16  caption_text_ro       7 non-null      object
#  17  caption_text_fr       8 non-null      object
#  18  caption_text_pt       9 non-null      object
#  19  caption_text_af       7 non-null      object
#  20  caption_text_ar       7 non-null      object
#  21  caption_text_bg       3 non-null      object
#  22  caption_text_zh       2 non-null      object
#  23  caption_text_da       3 non-null      object
#  24  caption_text_nl       3 non-null      object
#  25  caption_text_en       7 non-null      object
#  26  caption_text_fil      4 non-null      object
#  27  caption_text_de       7 non-null      object
#  28  caption_text_el       5 non-null      object
#  29  caption_text_iw       6 non-null      object
#  30  caption_text_hi       7 non-null      object
#  31  caption_text_id       4 non-null      object
#  32  caption_text_it       7 non-null      object
#  33  caption_text_ja       6 non-null      object
#  34  caption_text_ko       6 non-null      object
#  35  caption_text_no       4 non-null      object
#  36  caption_text_fa       6 non-null      object
#  37  caption_text_pl       5 non-null      object
#  38  caption_text_ru       7 non-null      object
#  39  caption_text_sv       4 non-null      object
#  40  caption_text_th       2 non-null      object
#  41  caption_text_uk       1 non-null      object
#  42  caption_text_vi       4 non-null      object
#  43  caption_text_cs       2 non-null      object
#  44  caption_text_de-CH    1 non-null      object
#  45  caption_text_hu       3 non-null      object
#  46  caption_text_hy       1 non-null      object
#  47  caption_text_az       1 non-null      object
#  48  caption_text_be       1 non-null      object
#  49  caption_text_bs       1 non-null      object
#  50  caption_text_zh-Hans  3 non-null      object
#  51  caption_text_hr       1 non-null      object
#  52  caption_text_sk       1 non-null      object
#  53  caption_text_sl       1 non-null      object
#  54  caption_text_uz       1 non-null      object
#  55  caption_text_zh-Hant  2 non-null      object
#  56  caption_text_ht       1 non-null      object
# dtypes: float64(4), int64(2), object(51)
# memory usage: 1.6+ MB

# %%
df_concatenado.dropna(subset="caption_text_es", inplace=True)

# %%
df_concatenado["channel_name"].value_counts()
# Out:
# channel_name
# USACRYPTONOTICIAS              891
# Bitcoin hoy                    842
# Bolsas Hoy | Esteban Pérez     401
# ARENA ALFA                     267
# Name: count, dtype: int64

# %%
df_concatenado.to_csv("data/df_full.csv", sep=";", index=False)
